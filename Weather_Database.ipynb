# %%
# import statements
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the Latitude and Longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, add it to the cities list.
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 618

# %%
# Import the request library.
import requests

from datetime import datetime
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
# List of city data.
city_data = []

# Print to logger.
print('Beginning Data Retrieval')
print('-' * 25)

# Create a counter.
record_count = 1
set_count = 1
for index, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = f"{url}&q={city.replace(' ', '+')}"
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_weather_description = city_weather['weather'][0]['description']
        try:
            city_rain_inches = city_weather['rain']['1h']
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather['snow']['1h']
        except KeyError:
            city_snow_inches = 0
            
        # Append the city information into city_data.
        city_data.append(
        {
            'City': city,
            'Lat': city_lat,
            'Lng': city_lng,
            'Max Temp': city_max_temp,
            'Current Description': city_weather_description,
            'Rain (inches)': city_rain_inches,
            'Snow (inches)': city_snow_inches,
            'Humidity': city_humidity,
            'Cloudiness': city_clouds,
            'Wind Speed': city_wind,
            'Country': city_country
        })
    except:
        print('City not found. Skipping...')
        pass
# Indicate that the Data Loading is complete.
print('-' * 20)
print('Data Retrieval Complete')
print('-' * 20)
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | roebourne
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | shubarkuduk
# Processing Record 5 of Set 1 | vardo
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | dalbandin
# Processing Record 8 of Set 1 | amuntai
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | guerrero negro
# Processing Record 11 of Set 1 | itarema
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | road town
# Processing Record 14 of Set 1 | ibatiba
# Processing Record 15 of Set 1 | cidreira
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | dikson
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 1 | shihezi
# Processing Record 24 of Set 1 | sobolevo
# Processing Record 25 of Set 1 | nishihara
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | tilichiki
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | saint-philippe
# Processing Record 30 of Set 1 | torbay
# Processing Record 31 of Set 1 | hamilton
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | kaitangata
# Processing Record 34 of Set 1 | kloulklubed
# Processing Record 35 of Set 1 | pacific grove
# Processing Record 36 of Set 1 | sri aman
# Processing Record 37 of Set 1 | yar-sale
# Processing Record 38 of Set 1 | sulangan
# Processing Record 39 of Set 1 | puerto carreno
# Processing Record 40 of Set 1 | kruisfontein
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | mar del plata
# Processing Record 43 of Set 1 | cayenne
# Processing Record 44 of Set 1 | saint-pierre
# Processing Record 45 of Set 1 | tasiilaq
# Processing Record 46 of Set 1 | nikolskoye
# Processing Record 47 of Set 1 | naze
# Processing Record 48 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 1 | havre-saint-pierre
# Processing Record 50 of Set 1 | ambon
# Processing Record 1 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 2 | pevek
# Processing Record 3 of Set 2 | qaanaaq
# Processing Record 4 of Set 2 | adrar
# Processing Record 5 of Set 2 | caucaia
# Processing Record 6 of Set 2 | jalu
# Processing Record 7 of Set 2 | hualmay
# Processing Record 8 of Set 2 | davila
# Processing Record 9 of Set 2 | abha
# Processing Record 10 of Set 2 | hobyo
# Processing Record 11 of Set 2 | labuhan
# Processing Record 12 of Set 2 | georgetown
# Processing Record 13 of Set 2 | sao filipe
# Processing Record 14 of Set 2 | bluff
# Processing Record 15 of Set 2 | new norfolk
# Processing Record 16 of Set 2 | avera
# Processing Record 17 of Set 2 | port elizabeth
# Processing Record 18 of Set 2 | skiros
# City not found. Skipping...
# Processing Record 19 of Set 2 | upernavik
# Processing Record 20 of Set 2 | hithadhoo
# Processing Record 21 of Set 2 | bengkulu
# Processing Record 22 of Set 2 | hvide sande
# Processing Record 23 of Set 2 | butaritari
# Processing Record 24 of Set 2 | samarai
# Processing Record 25 of Set 2 | sur
# Processing Record 26 of Set 2 | turan
# Processing Record 27 of Set 2 | isangel
# Processing Record 28 of Set 2 | anchorage
# Processing Record 29 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 2 | auki
# Processing Record 32 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 2 | lowicz
# Processing Record 34 of Set 2 | bandarbeyla
# Processing Record 35 of Set 2 | beisfjord
# Processing Record 36 of Set 2 | vostok
# Processing Record 37 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 2 | arraial do cabo
# Processing Record 39 of Set 2 | ishim
# Processing Record 40 of Set 2 | ippy
# Processing Record 41 of Set 2 | carire
# Processing Record 42 of Set 2 | mahebourg
# Processing Record 43 of Set 2 | saint-joseph
# Processing Record 44 of Set 2 | barrow
# Processing Record 45 of Set 2 | altus
# Processing Record 46 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 2 | atuona
# Processing Record 48 of Set 2 | touros
# Processing Record 49 of Set 2 | sochaczew
# Processing Record 50 of Set 2 | norman wells
# Processing Record 1 of Set 3 | cairns
# Processing Record 2 of Set 3 | salalah
# Processing Record 3 of Set 3 | erzin
# Processing Record 4 of Set 3 | gunjur
# Processing Record 5 of Set 3 | tuatapere
# Processing Record 6 of Set 3 | malartic
# Processing Record 7 of Set 3 | panzhihua
# Processing Record 8 of Set 3 | verkhnevilyuysk
# Processing Record 9 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 3 | ratnagiri
# Processing Record 11 of Set 3 | bilma
# Processing Record 12 of Set 3 | nome
# Processing Record 13 of Set 3 | fryanovo
# Processing Record 14 of Set 3 | lagoa
# Processing Record 15 of Set 3 | rawlins
# Processing Record 16 of Set 3 | narsaq
# Processing Record 17 of Set 3 | mount gambier
# Processing Record 18 of Set 3 | pak phanang
# Processing Record 19 of Set 3 | sini
# Processing Record 20 of Set 3 | yulara
# Processing Record 21 of Set 3 | port lincoln
# Processing Record 22 of Set 3 | union
# Processing Record 23 of Set 3 | margate
# Processing Record 24 of Set 3 | bac can
# City not found. Skipping...
# Processing Record 25 of Set 3 | vaini
# Processing Record 26 of Set 3 | sturgis
# Processing Record 27 of Set 3 | karpogory
# Processing Record 28 of Set 3 | longyearbyen
# Processing Record 29 of Set 3 | saskylakh
# Processing Record 30 of Set 3 | atasu
# Processing Record 31 of Set 3 | tiksi
# Processing Record 32 of Set 3 | kalabo
# Processing Record 33 of Set 3 | khanu woralaksaburi
# Processing Record 34 of Set 3 | punta alta
# Processing Record 35 of Set 3 | topolobampo
# Processing Record 36 of Set 3 | jamestown
# Processing Record 37 of Set 3 | saldanha
# Processing Record 38 of Set 3 | staryy nadym
# Processing Record 39 of Set 3 | warri
# Processing Record 40 of Set 3 | hare bay
# Processing Record 41 of Set 3 | ambilobe
# Processing Record 42 of Set 3 | castro
# Processing Record 43 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 3 | constantine
# Processing Record 45 of Set 3 | tara
# Processing Record 46 of Set 3 | khatanga
# Processing Record 47 of Set 3 | trairi
# Processing Record 48 of Set 3 | aldan
# Processing Record 49 of Set 3 | sangar
# Processing Record 50 of Set 3 | omboue
# Processing Record 1 of Set 4 | tuktoyaktuk
# Processing Record 2 of Set 4 | esperance
# Processing Record 3 of Set 4 | souillac
# Processing Record 4 of Set 4 | oistins
# Processing Record 5 of Set 4 | dwarka
# Processing Record 6 of Set 4 | dingle
# Processing Record 7 of Set 4 | ngama
# Processing Record 8 of Set 4 | ilulissat
# Processing Record 9 of Set 4 | yellowknife
# Processing Record 10 of Set 4 | manaure
# Processing Record 11 of Set 4 | airai
# Processing Record 12 of Set 4 | mayumba
# Processing Record 13 of Set 4 | kunming
# Processing Record 14 of Set 4 | namatanai
# Processing Record 15 of Set 4 | ati
# Processing Record 16 of Set 4 | bambous virieux
# Processing Record 17 of Set 4 | vanimo
# Processing Record 18 of Set 4 | colares
# Processing Record 19 of Set 4 | aswan
# Processing Record 20 of Set 4 | kenitra
# Processing Record 21 of Set 4 | doha
# Processing Record 22 of Set 4 | rotenburg
# Processing Record 23 of Set 4 | sedelnikovo
# City not found. Skipping...
# Processing Record 24 of Set 4 | aykino
# Processing Record 25 of Set 4 | north bend
# Processing Record 26 of Set 4 | phan thiet
# Processing Record 27 of Set 4 | provideniya
# Processing Record 28 of Set 4 | ahipara
# Processing Record 29 of Set 4 | faanui
# Processing Record 30 of Set 4 | ritchie
# Processing Record 31 of Set 4 | inongo
# Processing Record 32 of Set 4 | guia lopes da laguna
# Processing Record 33 of Set 4 | leningradskiy
# Processing Record 34 of Set 4 | sisimiut
# Processing Record 35 of Set 4 | narok
# Processing Record 36 of Set 4 | sile
# Processing Record 37 of Set 4 | hasaki
# Processing Record 38 of Set 4 | zhanakorgan
# Processing Record 39 of Set 4 | barao de melgaco
# Processing Record 40 of Set 4 | geraldton
# Processing Record 41 of Set 4 | bellefontaine
# Processing Record 42 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 44 of Set 4 | ubatuba
# Processing Record 45 of Set 4 | honningsvag
# Processing Record 46 of Set 4 | freeport
# Processing Record 47 of Set 4 | bubaque
# Processing Record 48 of Set 4 | lorengau
# Processing Record 49 of Set 4 | sabang
# Processing Record 50 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 5 | astana
# Processing Record 2 of Set 5 | khandyga
# Processing Record 3 of Set 5 | rawson
# Processing Record 4 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 5 of Set 5 | marsh harbour
# Processing Record 6 of Set 5 | nanortalik
# Processing Record 7 of Set 5 | diamantino
# Processing Record 8 of Set 5 | biak
# Processing Record 9 of Set 5 | cape elizabeth
# City not found. Skipping...
# Processing Record 10 of Set 5 | cherskiy
# Processing Record 11 of Set 5 | clyde river
# Processing Record 12 of Set 5 | panacan
# Processing Record 13 of Set 5 | chapleau
# Processing Record 14 of Set 5 | hofn
# Processing Record 15 of Set 5 | port hardy
# Processing Record 16 of Set 5 | kieta
# Processing Record 17 of Set 5 | manthani
# Processing Record 18 of Set 5 | prince rupert
# Processing Record 19 of Set 5 | genhe
# Processing Record 20 of Set 5 | farafangana
# Processing Record 21 of Set 5 | lasa
# Processing Record 22 of Set 5 | kalmar
# Processing Record 23 of Set 5 | lebu
# Processing Record 24 of Set 5 | iqaluit
# Processing Record 25 of Set 5 | bethel
# Processing Record 26 of Set 5 | robe
# Processing Record 27 of Set 5 | tlahualilo
# City not found. Skipping...
# Processing Record 28 of Set 5 | careiro da varzea
# Processing Record 29 of Set 5 | kambove
# Processing Record 30 of Set 5 | port-cartier
# Processing Record 31 of Set 5 | luorong
# Processing Record 32 of Set 5 | hokitika
# Processing Record 33 of Set 5 | mikhaylovsk
# Processing Record 34 of Set 5 | ribeira grande
# Processing Record 35 of Set 5 | berlevag
# Processing Record 36 of Set 5 | douala
# Processing Record 37 of Set 5 | mayo
# Processing Record 38 of Set 5 | yerbogachen
# Processing Record 39 of Set 5 | tutoia
# Processing Record 40 of Set 5 | surt
# Processing Record 41 of Set 5 | skage
# City not found. Skipping...
# Processing Record 42 of Set 5 | aklavik
# Processing Record 43 of Set 5 | kiruna
# Processing Record 44 of Set 5 | frontignan
# Processing Record 45 of Set 5 | ornskoldsvik
# Processing Record 46 of Set 5 | hirara
# Processing Record 47 of Set 5 | lyuban
# Processing Record 48 of Set 5 | atbasar
# Processing Record 49 of Set 5 | kundiawa
# Processing Record 50 of Set 5 | nawabganj
# Processing Record 1 of Set 6 | weihe
# Processing Record 2 of Set 6 | sao joao del rei
# Processing Record 3 of Set 6 | vung tau
# Processing Record 4 of Set 6 | ciudad bolivar
# Processing Record 5 of Set 6 | namibe
# Processing Record 6 of Set 6 | pangnirtung
# Processing Record 7 of Set 6 | sola
# Processing Record 8 of Set 6 | hervey bay
# Processing Record 9 of Set 6 | nador
# Processing Record 10 of Set 6 | kargasok
# Processing Record 11 of Set 6 | barcelos
# Processing Record 12 of Set 6 | sumenep
# Processing Record 13 of Set 6 | college
# Processing Record 14 of Set 6 | qena
# Processing Record 15 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 6 | morondava
# Processing Record 17 of Set 6 | beringovskiy
# Processing Record 18 of Set 6 | taltal
# Processing Record 19 of Set 6 | coos bay
# Processing Record 20 of Set 6 | segou
# Processing Record 21 of Set 6 | pangody
# Processing Record 22 of Set 6 | cabo san lucas
# Processing Record 23 of Set 6 | lowestoft
# City not found. Skipping...
# Processing Record 24 of Set 6 | lavrentiya
# City not found. Skipping...
# Processing Record 25 of Set 6 | vila velha
# City not found. Skipping...
# Processing Record 26 of Set 6 | camacha
# Processing Record 27 of Set 6 | quatre cocos
# Processing Record 28 of Set 6 | novyy urengoy
# Processing Record 29 of Set 6 | burkhala
# City not found. Skipping...
# Processing Record 30 of Set 6 | umm lajj
# Processing Record 31 of Set 6 | praia da vitoria
# Processing Record 32 of Set 6 | takoradi
# Processing Record 33 of Set 6 | deputatskiy
# Processing Record 34 of Set 6 | hilo
# Processing Record 35 of Set 6 | vila
# Processing Record 36 of Set 6 | jutai
# Processing Record 37 of Set 6 | santander
# Processing Record 38 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 6 | cervo
# Processing Record 40 of Set 6 | vao
# Processing Record 41 of Set 6 | la ronge
# Processing Record 42 of Set 6 | paamiut
# Processing Record 43 of Set 6 | nowy dwor gdanski
# Processing Record 44 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 6 | hodmezovasarhely
# Processing Record 46 of Set 6 | hovd
# Processing Record 47 of Set 6 | carmen
# Processing Record 48 of Set 6 | inhambane
# Processing Record 49 of Set 6 | khash
# Processing Record 50 of Set 6 | dunoon
# Processing Record 1 of Set 7 | alugan
# Processing Record 2 of Set 7 | richards bay
# Processing Record 3 of Set 7 | nelson bay
# Processing Record 4 of Set 7 | portland
# Processing Record 5 of Set 7 | eyl
# Processing Record 6 of Set 7 | yozgat
# Processing Record 7 of Set 7 | labrea
# Processing Record 8 of Set 7 | tadine
# Processing Record 9 of Set 7 | severo-kurilsk
# Processing Record 10 of Set 7 | sungaipenuh
# Processing Record 11 of Set 7 | erdenet
# Processing Record 12 of Set 7 | east london
# Processing Record 13 of Set 7 | bafq
# Processing Record 14 of Set 7 | buraydah
# Processing Record 15 of Set 7 | unity
# Processing Record 16 of Set 7 | rylsk
# Processing Record 17 of Set 7 | chuy
# Processing Record 18 of Set 7 | ifanadiana
# Processing Record 19 of Set 7 | gornopravdinsk
# Processing Record 20 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 21 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 22 of Set 7 | mizdah
# Processing Record 23 of Set 7 | cusuna
# Processing Record 24 of Set 7 | umm jarr
# City not found. Skipping...
# Processing Record 25 of Set 7 | nioro
# Processing Record 26 of Set 7 | riyadh
# Processing Record 27 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 7 | nantucket
# Processing Record 29 of Set 7 | necochea
# Processing Record 30 of Set 7 | evanston
# Processing Record 31 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 7 | ixtapa
# Processing Record 33 of Set 7 | verin
# Processing Record 34 of Set 7 | keningau
# Processing Record 35 of Set 7 | kailua
# Processing Record 36 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 7 | klaeng
# Processing Record 38 of Set 7 | saint-leu
# Processing Record 39 of Set 7 | camacari
# Processing Record 40 of Set 7 | westerland
# Processing Record 41 of Set 7 | ushtobe
# Processing Record 42 of Set 7 | tiarei
# Processing Record 43 of Set 7 | marsa matruh
# Processing Record 44 of Set 7 | cedro
# Processing Record 45 of Set 7 | ancud
# Processing Record 46 of Set 7 | ponta do sol
# Processing Record 47 of Set 7 | grand gaube
# Processing Record 48 of Set 7 | vicuna
# Processing Record 49 of Set 7 | port shepstone
# Processing Record 50 of Set 7 | myitkyina
# Processing Record 1 of Set 8 | riberalta
# Processing Record 2 of Set 8 | leiyang
# Processing Record 3 of Set 8 | novobelokatay
# Processing Record 4 of Set 8 | huarmey
# Processing Record 5 of Set 8 | zhaoqing
# Processing Record 6 of Set 8 | northam
# Processing Record 7 of Set 8 | abbotsford
# Processing Record 8 of Set 8 | carupano
# Processing Record 9 of Set 8 | nalut
# Processing Record 10 of Set 8 | maraba
# Processing Record 11 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 8 | wanaka
# Processing Record 13 of Set 8 | maumere
# Processing Record 14 of Set 8 | kodiak
# Processing Record 15 of Set 8 | nalhati
# Processing Record 16 of Set 8 | konosha
# Processing Record 17 of Set 8 | kyabe
# Processing Record 18 of Set 8 | nouadhibou
# Processing Record 19 of Set 8 | visnes
# Processing Record 20 of Set 8 | ovsyanka
# Processing Record 21 of Set 8 | livani
# Processing Record 22 of Set 8 | bouza
# Processing Record 23 of Set 8 | el tigre
# Processing Record 24 of Set 8 | mokhotlong
# Processing Record 25 of Set 8 | kosa
# Processing Record 26 of Set 8 | salta
# Processing Record 27 of Set 8 | padang
# Processing Record 28 of Set 8 | carnarvon
# Processing Record 29 of Set 8 | japura
# Processing Record 30 of Set 8 | bulaevo
# Processing Record 31 of Set 8 | sorland
# Processing Record 32 of Set 8 | kirakira
# Processing Record 33 of Set 8 | agde
# Processing Record 34 of Set 8 | tezu
# Processing Record 35 of Set 8 | rudbar
# Processing Record 36 of Set 8 | bykovo
# Processing Record 37 of Set 8 | san matias
# Processing Record 38 of Set 8 | okato
# Processing Record 39 of Set 8 | alyangula
# Processing Record 40 of Set 8 | mahajanga
# Processing Record 41 of Set 8 | ostrovnoy
# Processing Record 42 of Set 8 | shirgaon
# Processing Record 43 of Set 8 | egvekinot
# Processing Record 44 of Set 8 | antofagasta
# Processing Record 45 of Set 8 | kaoma
# Processing Record 46 of Set 8 | gweru
# Processing Record 47 of Set 8 | pisco
# Processing Record 48 of Set 8 | kavieng
# Processing Record 49 of Set 8 | garango
# Processing Record 50 of Set 8 | viedma
# Processing Record 1 of Set 9 | flinders
# Processing Record 2 of Set 9 | gatton
# Processing Record 3 of Set 9 | vanavara
# Processing Record 4 of Set 9 | mattru
# Processing Record 5 of Set 9 | salas
# Processing Record 6 of Set 9 | santa fe
# Processing Record 7 of Set 9 | bac lieu
# Processing Record 8 of Set 9 | sioux lookout
# Processing Record 9 of Set 9 | nizhniy chir
# Processing Record 10 of Set 9 | bonavista
# Processing Record 11 of Set 9 | mehamn
# Processing Record 12 of Set 9 | boueni
# Processing Record 13 of Set 9 | port alberni
# Processing Record 14 of Set 9 | itai
# Processing Record 15 of Set 9 | erdemli
# Processing Record 16 of Set 9 | ossora
# Processing Record 17 of Set 9 | rabo de peixe
# Processing Record 18 of Set 9 | makakilo city
# Processing Record 19 of Set 9 | kisangani
# Processing Record 20 of Set 9 | dinajpur
# Processing Record 21 of Set 9 | talnakh
# Processing Record 22 of Set 9 | seoul
# Processing Record 23 of Set 9 | gamba
# Processing Record 24 of Set 9 | noumea
# Processing Record 25 of Set 9 | qurbah
# City not found. Skipping...
# Processing Record 26 of Set 9 | magadan
# Processing Record 27 of Set 9 | tabou
# Processing Record 28 of Set 9 | sao jose
# Processing Record 29 of Set 9 | pontian kecil
# Processing Record 30 of Set 9 | haines junction
# Processing Record 31 of Set 9 | los llanos de aridane
# Processing Record 32 of Set 9 | san quintin
# Processing Record 33 of Set 9 | ponta delgada
# Processing Record 34 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 9 | maragogi
# Processing Record 36 of Set 9 | dzaoudzi
# Processing Record 37 of Set 9 | waterloo
# Processing Record 38 of Set 9 | penzance
# Processing Record 39 of Set 9 | oussouye
# Processing Record 40 of Set 9 | rehoboth
# Processing Record 41 of Set 9 | blackwater
# Processing Record 42 of Set 9 | sakakah
# Processing Record 43 of Set 9 | embu
# Processing Record 44 of Set 9 | bosobolo
# Processing Record 45 of Set 9 | centralia
# Processing Record 46 of Set 9 | husavik
# Processing Record 47 of Set 9 | avarua
# Processing Record 48 of Set 9 | chichimila
# Processing Record 49 of Set 9 | la paz
# Processing Record 50 of Set 9 | wasilla
# Processing Record 1 of Set 10 | mutare
# Processing Record 2 of Set 10 | valparaiso
# Processing Record 3 of Set 10 | tura
# Processing Record 4 of Set 10 | north platte
# Processing Record 5 of Set 10 | ust-kuyga
# Processing Record 6 of Set 10 | acapulco
# Processing Record 7 of Set 10 | sitka
# Processing Record 8 of Set 10 | kyritz
# Processing Record 9 of Set 10 | bosilegrad
# Processing Record 10 of Set 10 | homer
# Processing Record 11 of Set 10 | solton
# Processing Record 12 of Set 10 | aykhal
# Processing Record 13 of Set 10 | fort nelson
# Processing Record 14 of Set 10 | lebedinyy
# Processing Record 15 of Set 10 | esmeraldas
# Processing Record 16 of Set 10 | jamame
# Processing Record 17 of Set 10 | bontang
# Processing Record 18 of Set 10 | merauke
# Processing Record 19 of Set 10 | caravelas
# Processing Record 20 of Set 10 | sinjah
# City not found. Skipping...
# Processing Record 21 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 10 | lantawan
# Processing Record 23 of Set 10 | half moon bay
# Processing Record 24 of Set 10 | teahupoo
# Processing Record 25 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 26 of Set 10 | omsukchan
# Processing Record 27 of Set 10 | loutra ipatis
# City not found. Skipping...
# Processing Record 28 of Set 10 | filadelfia
# Processing Record 29 of Set 10 | toyooka
# Processing Record 30 of Set 10 | cristalina
# Processing Record 31 of Set 10 | kalmunai
# Processing Record 32 of Set 10 | rio gallegos
# Processing Record 33 of Set 10 | meulaboh
# Processing Record 34 of Set 10 | jiuquan
# Processing Record 35 of Set 10 | thompson
# Processing Record 36 of Set 10 | chokurdakh
# Processing Record 37 of Set 10 | gojra
# Processing Record 38 of Set 10 | the valley
# Processing Record 39 of Set 10 | fairbanks
# Processing Record 40 of Set 10 | tachov
# Processing Record 41 of Set 10 | raudeberg
# Processing Record 42 of Set 10 | enid
# Processing Record 43 of Set 10 | grindavik
# Processing Record 44 of Set 10 | port moresby
# Processing Record 45 of Set 10 | cabedelo
# Processing Record 46 of Set 10 | winsum
# Processing Record 47 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 48 of Set 10 | rundu
# Processing Record 49 of Set 10 | eirunepe
# Processing Record 50 of Set 10 | komsomolskiy
# Processing Record 1 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 2 of Set 11 | lyngseidet
# Processing Record 3 of Set 11 | turbat
# Processing Record 4 of Set 11 | brand-erbisdorf
# Processing Record 5 of Set 11 | tahoua
# Processing Record 6 of Set 11 | westport
# Processing Record 7 of Set 11 | superior
# Processing Record 8 of Set 11 | kawalu
# Processing Record 9 of Set 11 | mahmudabad
# Processing Record 10 of Set 11 | walvis bay
# Processing Record 11 of Set 11 | dongobesh
# Processing Record 12 of Set 11 | domanivka
# Processing Record 13 of Set 11 | doksy
# Processing Record 14 of Set 11 | srednekolymsk
# Processing Record 15 of Set 11 | vila franca do campo
# Processing Record 16 of Set 11 | akonolinga
# Processing Record 17 of Set 11 | jiangyou
# Processing Record 18 of Set 11 | mount isa
# Processing Record 19 of Set 11 | olafsvik
# Processing Record 20 of Set 11 | varhaug
# Processing Record 21 of Set 11 | karratha
# Processing Record 22 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 23 of Set 11 | massaguet
# Processing Record 24 of Set 11 | kigoma
# Processing Record 25 of Set 11 | tessalit
# Processing Record 26 of Set 11 | te anau
# Processing Record 27 of Set 11 | cururupu
# Processing Record 28 of Set 11 | sovetskiy
# Processing Record 29 of Set 11 | naryan-mar
# Processing Record 30 of Set 11 | pittsburg
# Processing Record 31 of Set 11 | xining
# Processing Record 32 of Set 11 | klaksvik
# Processing Record 33 of Set 11 | lumberton
# Processing Record 34 of Set 11 | lensk
# Processing Record 35 of Set 11 | beloha
# Processing Record 36 of Set 11 | oranjemund
# Processing Record 37 of Set 11 | waipawa
# Processing Record 38 of Set 11 | monrovia
# Processing Record 39 of Set 11 | chlorakas
# Processing Record 40 of Set 11 | gwadar
# Processing Record 41 of Set 11 | calama
# Processing Record 42 of Set 11 | dongsheng
# Processing Record 43 of Set 11 | saint george
# Processing Record 44 of Set 11 | vertientes
# Processing Record 45 of Set 11 | hidalgo
# Processing Record 46 of Set 11 | victoria
# Processing Record 47 of Set 11 | bone
# Processing Record 48 of Set 11 | natal
# Processing Record 49 of Set 11 | qasigiannguit
# Processing Record 50 of Set 11 | zaysan
# Processing Record 1 of Set 12 | karakol
# Processing Record 2 of Set 12 | brae
# Processing Record 3 of Set 12 | maniitsoq
# Processing Record 4 of Set 12 | sakaiminato
# Processing Record 5 of Set 12 | bambanglipuro
# Processing Record 6 of Set 12 | marquette
# Processing Record 7 of Set 12 | galle
# Processing Record 8 of Set 12 | rio grande
# Processing Record 9 of Set 12 | bongandanga
# Processing Record 10 of Set 12 | san pedro
# Processing Record 11 of Set 12 | kenai
# Processing Record 12 of Set 12 | tautira
# Processing Record 13 of Set 12 | weligama
# Processing Record 14 of Set 12 | san patricio
# Processing Record 15 of Set 12 | arys
# Processing Record 16 of Set 12 | santa rosa
# Processing Record 17 of Set 12 | shimoda
# Processing Record 18 of Set 12 | luhyny
# Processing Record 19 of Set 12 | pochutla
# Processing Record 20 of Set 12 | kununurra
# Processing Record 21 of Set 12 | kandalaksha
# Processing Record 22 of Set 12 | andros town
# Processing Record 23 of Set 12 | joshimath
# Processing Record 24 of Set 12 | yumen
# Processing Record 25 of Set 12 | pacifica
# Processing Record 26 of Set 12 | dicabisagan
# Processing Record 27 of Set 12 | lins
# Processing Record 28 of Set 12 | boa vista
# Processing Record 29 of Set 12 | kiunga
# Processing Record 30 of Set 12 | abu samrah
# Processing Record 31 of Set 12 | santa maria
# Processing Record 32 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 33 of Set 12 | san cristobal
# Processing Record 34 of Set 12 | sidi qasim
# City not found. Skipping...
# Processing Record 35 of Set 12 | pathein
# Processing Record 36 of Set 12 | henties bay
# Processing Record 37 of Set 12 | panormos
# Processing Record 38 of Set 12 | elblag
# Processing Record 39 of Set 12 | qaqortoq
# Processing Record 40 of Set 12 | udaipura
# Processing Record 41 of Set 12 | xuddur
# Processing Record 42 of Set 12 | chapais
# Processing Record 43 of Set 12 | bida
# Processing Record 44 of Set 12 | aasiaat
# Processing Record 45 of Set 12 | udimskiy
# Processing Record 46 of Set 12 | meiktila
# Processing Record 47 of Set 12 | kahului
# Processing Record 48 of Set 12 | hambantota
# Processing Record 49 of Set 12 | jardim
# Processing Record 50 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 13 | jacmel
# Processing Record 2 of Set 13 | mafinga
# Processing Record 3 of Set 13 | aripuana
# Processing Record 4 of Set 13 | vredendal
# Processing Record 5 of Set 13 | cheyenne
# Processing Record 6 of Set 13 | wanganui
# Processing Record 7 of Set 13 | tual
# Processing Record 8 of Set 13 | kuching
# Processing Record 9 of Set 13 | vallenar
# Processing Record 10 of Set 13 | alofi
# Processing Record 11 of Set 13 | nortelandia
# Processing Record 12 of Set 13 | alekseyevsk
# Processing Record 13 of Set 13 | mocuba
# Processing Record 14 of Set 13 | zheleznodorozhnyy
# Processing Record 15 of Set 13 | cooma
# Processing Record 16 of Set 13 | pulandian
# Processing Record 17 of Set 13 | ginda
# Processing Record 18 of Set 13 | dergachi
# --------------------
# Data Retrieval Complete
# --------------------

# %%
len(city_data)
# Out:
# 572

# %%
# convert list of dictionaries to a pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp Current Description  \
# 0      bredasdorp -34.5322   20.0403     63.43     overcast clouds
# 1       roebourne -20.7833  117.1333     79.66           clear sky
# 2         ushuaia -54.8000  -68.3000     56.86       broken clouds
# 3     shubarkuduk  49.1447   56.4872     56.62     overcast clouds
# 4           vardo  70.3705   31.1107     29.61     overcast clouds
# 5     port alfred -33.5906   26.8910     62.19       broken clouds
# 6       dalbandin  28.8947   64.4101     73.20           clear sky
# 7         amuntai  -2.4177  115.2494     73.09     overcast clouds
# 8    puerto ayora  -0.7393  -90.3518     84.16       broken clouds
# 9  guerrero negro  27.9769 -114.0611     70.70          few clouds
#
#    Rain (inches)  Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0            0.0            0.0        86          99        5.88      ZA
# 1            0.0            0.0        36           7        6.31      AU
# 2            0.0            0.0        58          75        5.75      AR
# 3            0.0            0.0        74         100       11.65      KZ
# 4            0.0            0.0        72          91        7.78      NO
# 5            0.0            0.0        94          52        4.00      ZA
# 6            0.0            0.0        10           0        3.38      PK
# 7            0.0            0.0        99          86        0.81      ID
# 8            0.0            0.0        79          75       10.36      EC
# 9            0.0            0.0        37          22       16.22      MX

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 
                    'Cloudiness', 'Wind Speed', 'Current Description', 
                    'Rain (inches)', 'Snow (inches)']

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      bredasdorp      ZA -34.5322   20.0403     63.43        86          99
# 1       roebourne      AU -20.7833  117.1333     79.66        36           7
# 2         ushuaia      AR -54.8000  -68.3000     56.86        58          75
# 3     shubarkuduk      KZ  49.1447   56.4872     56.62        74         100
# 4           vardo      NO  70.3705   31.1107     29.61        72          91
# 5     port alfred      ZA -33.5906   26.8910     62.19        94          52
# 6       dalbandin      PK  28.8947   64.4101     73.20        10           0
# 7         amuntai      ID  -2.4177  115.2494     73.09        99          86
# 8    puerto ayora      EC  -0.7393  -90.3518     84.16        79          75
# 9  guerrero negro      MX  27.9769 -114.0611     70.70        37          22
#
#    Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0        5.88     overcast clouds            0.0            0.0
# 1        6.31           clear sky            0.0            0.0
# 2        5.75       broken clouds            0.0            0.0
# 3       11.65     overcast clouds            0.0            0.0
# 4        7.78     overcast clouds            0.0            0.0
# 5        4.00       broken clouds            0.0            0.0
# 6        3.38           clear sky            0.0            0.0
# 7        0.81     overcast clouds            0.0            0.0
# 8       10.36       broken clouds            0.0            0.0
# 9       16.22          few clouds            0.0            0.0

# %%
raining_cities = city_data_df.loc[city_data_df['Rain (inches)'] > 0]
raining_cities.head()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 15          hobart      AU -42.8794  147.3294     52.27        84           0
# 17         mataura      NZ -46.1927  168.8643     52.48        68          61
# 23        hermanus      ZA -34.4187   19.2345     63.72        88         100
# 26  saint-philippe      RE -21.3585   55.7679     74.79        89          81
# 31     kloulklubed      PW   7.0419  134.2556     83.25        79         100
#
#     Wind Speed   Current Description  Rain (inches)  Snow (inches)
# 15        6.91            light rain           0.13            0.0
# 17        2.37            light rain           0.97            0.0
# 23        8.84            light rain           0.11            0.0
# 26       16.17            light rain           0.95            0.0
# 31       18.25  heavy intensity rain           4.86            0.0

# %%
snowing_cities = city_data_df.loc[city_data_df['Snow (inches)'] > 0]
snowing_cities
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 97   verkhnevilyuysk      RU  63.4453  120.3167     27.61        96
# 114        karpogory      RU  64.0019   44.4451     29.82        95
# 217      yerbogachen      RU  61.2767  108.0108     31.39        96
# 244     beringovskiy      RU  63.0500  179.3167     27.99        97
# 280   severo-kurilsk      RU  50.6789  156.1250     29.64        85
# 386          talnakh      RU  69.4865   88.3972     22.68        97
# 459       lyngseidet      NO  69.5763   20.2189     32.00        96
# 464         superior      US  46.7208  -92.1041     36.75        96
# 485       naryan-mar      RU  67.6713   53.0870     27.93        97
# 490            lensk      RU  60.7253  114.9278     30.92        93
# 512        marquette      US  46.5333  -87.6335     36.84        97
#
#      Cloudiness  Wind Speed Current Description  Rain (inches)  Snow (inches)
# 97          100        8.05          light snow            0.0           0.24
# 114         100       10.74          light snow            0.0           0.17
# 217         100       15.77                snow            0.0           0.80
# 244         100        9.53                snow            0.0           1.31
# 280         100       23.02          light snow            0.0           0.28
# 386         100        5.06          light snow            0.0           0.36
# 459          99        0.56          light snow            0.0           0.11
# 464         100       12.66                snow            0.0           1.13
# 485         100       15.46                snow            0.0           0.55
# 490         100       16.37          light snow            0.0           0.23
# 512         100        7.07          light snow            0.0           0.31

# %%
# Create the output file (CSV).
output_data_file = 'Weather_Database/WeatherPy_database.csv'
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label='City_ID')
